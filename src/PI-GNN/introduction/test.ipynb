# %%
# librairies
import numpy as np
import jax.numpy as jnp
import jraph
import networkx as nx

# personal librairies 
import element_mesh_fractal
import utils

# %%
import graph_handling as gr_ha
import pickle


graph = gr_ha.build_toy_graph()

with open('some_graph.pickle', 'wb') as f:
    pickle.dump(graph, f)

with open('some_graph.pickle','rb') as f:
    new_graph = pickle.load(f)
# Out:
# build_toy_graph with n_subdivision = 2

# %%
gr_ha.draw_jraph_graph_structure(graph)

# %%
gr_ha.draw_jraph_graph_structure(new_graph)
